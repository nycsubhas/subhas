# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import broadcast

spark = SparkSession.builder.appName("BroadcastExample").getOrCreate()

# Large dataset
df_large = spark.range(0, 1000000).withColumnRenamed("id", "user_id")

# Small lookup dataset
df_small = spark.createDataFrame([(1, "A"), (2, "B"), (3, "C")], ["user_id", "category"])

# Broadcast join
df_joined = df_large.join(broadcast(df_small), "user_id")

df_joined.explain(True)
# Out:
# 25/11/07 19:22:34 WARN Utils: Your hostname, user-HP-Pavilion-x360-Convertible-14-dh0xxx resolves to a loopback address: 127.0.1.1; using 192.168.1.24 instead (on interface wlo1)
# 25/11/07 19:22:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/07 19:22:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/07 19:22:35 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/11/07 19:22:35 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/11/07 19:22:35 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [user_id])
# :- Project [id#0L AS user_id#2L]
# :  +- Range (0, 1000000, step=1, splits=Some(4))
# +- ResolvedHint (strategy=broadcast)
#    +- LogicalRDD [user_id#4L, category#5], false
#
# == Analyzed Logical Plan ==
# user_id: bigint, category: string
# Project [user_id#2L, category#5]
# +- Join Inner, (user_id#2L = user_id#4L)
#    :- Project [id#0L AS user_id#2L]
#    :  +- Range (0, 1000000, step=1, splits=Some(4))
#    +- ResolvedHint (strategy=broadcast)
#       +- LogicalRDD [user_id#4L, category#5], false
#
# == Optimized Logical Plan ==
# Project [user_id#2L, category#5]
# +- Join Inner, (user_id#2L = user_id#4L), rightHint=(strategy=broadcast)
#    :- Project [id#0L AS user_id#2L]
#    :  +- Range (0, 1000000, step=1, splits=Some(4))
#    +- Filter isnotnull(user_id#4L)
#       +- LogicalRDD [user_id#4L, category#5], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [user_id#2L, category#5]
#    +- BroadcastHashJoin [user_id#2L], [user_id#4L], Inner, BuildRight, false
#       :- Project [id#0L AS user_id#2L]
#       :  +- Range (0, 1000000, step=1, splits=4)
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]),false), [plan_id=24]
#          +- Filter isnotnull(user_id#4L)
#             +- Scan ExistingRDD[user_id#4L,category#5]
